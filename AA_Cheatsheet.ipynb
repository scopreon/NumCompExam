# %%
'''Cheatsheet'''
#%run 'WS03 - Triangular systems and Gaussian elimination.ipynb'
import copy

#math.ceil(x)
#math.floor(x)
#round(x) #round to 0 decimal places
#round(x, 2) #round to 2 decimal places

#a ** b #a to the power of b
#math.sqrt(x)

#math.sin(angle)
#math.cos(angle)
#math.log(x)
#math.pi

'''numpy'''
import numpy as np
#np.int64
#np.float32
# np.finfo(np.double)

# eps = np.finfo(float).eps
# dx = np.sqrt(eps)

#A = A.astype(np.float64)

#np.isclose(A[i, j], 0.0)

#numpy_array.shape
#np.append(other_array)
#np.insert(my_array, 1, 5)
#np.delete(my_array, [1])
#np.concatenate((arr1, arr2),axis=0)

'''Matrices'''
# np.info(np.ndarray.dtype) #help
#a.dot(b)
#a.transpose()
# np.matmul(A,x) #Multiply two numpy arrays

# from numpy import linalg as LA
# (LA.norm(r)) #Euclidean norm

'''SciPi'''
from scipy import linalg, sparse
# A = np.matrix(np.array([[1,-2], [3, 4]])) #Creating Matrices
# A.I #Inverse 
#linalg.inv(A) #Inverse
# A.T #Tranpose matrix
#np.trace(A) #Trace
# linalg.solve(A,b) #Solver for dense matrices
# np.linalg.solve(U,b) #Solver for dense matrices
# linalg.lstsq(D,E) #Least-squares solution to linear matrix equation
# P,L,U = linalg.lu(A) #LU Decomposition

from scipy import optimize
# root = optimize.brentq(f, -1, 10, full_output=True)
# print(root)

'''Pandas'''
import pandas as pd
# table_headings = ["n", "piS", "error"]
# table_data = []
# table_data.append([n, piS, abs(piS - np.pi*np.pi)])
# pd.DataFrame(table_data, columns=table_headings)

'''Matplotlib'''
import matplotlib.pyplot as plt
# fig = plt.figure()
# plt.plot(t, d, "-r", label="Euler method")
# plt.plot(t, de, "-b", label="Exact solution")
# plt.legend(loc="upper left")
# plt.xlabel("t")
# plt.ylabel("d")
# plt.grid()
# plt.show()
